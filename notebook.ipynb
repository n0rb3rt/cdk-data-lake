# %%
from pyspark.context import SparkContext
from awsglue.context import GlueContext

glue = GlueContext(SparkContext.getOrCreate())

# %%
crimes = glue.create_dynamic_frame.from_catalog("jnme-ab3-v1-clean", "crimes", transformation_ctx="source")

# %%
crimes.toDF().limit(10).toPandas().head(10)
# Out:
#          id case_number                date                 block  iucr  \
# 0   9742058    HX392289 2014-07-16 10:00:00     115XX W TOUHY AVE  0820
# 1   9819178    HX468762 2014-10-15 13:30:00   069XX N CENTRAL AVE  1153
# 2   9827727    HX464897 2014-10-12 14:30:00   065XX N MANNHEIM RD  1320
# 3  10809893    JA109211 2006-12-30 14:00:00  031XX W ROOSEVELT RD  1153
# 4  10992846    JA319757 2006-11-28 00:00:00   032XX W FULTON BLVD  1153
# 5  11339107    JB295436 2006-09-01 00:01:00  028XX W JACKSON BLVD  1153
# 6  11345360    JB303675 2006-06-01 00:00:00     031XX W MONROE ST  1153
# 7  11422600    JB404529 2006-08-01 00:01:00  002XX N KEYSTONE AVE  1153
# 8      3487    HM154020 2006-01-30 19:10:00    011XX N KEELER AVE  0110
# 9      3488    HM154020 2006-01-30 22:15:00    011XX N KEELER AVE  0110
#
#          primary_type                          description  \
# 0               THEFT                       $500 AND UNDER
# ...
